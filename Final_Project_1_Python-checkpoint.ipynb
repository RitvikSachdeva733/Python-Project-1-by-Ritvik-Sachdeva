# %%
n=int(input())
K=int(input())
while True :
    
    def o0(x,j,K):
        if (x==0 or j==0 or x==K-1 or j==K-3)and(not(((x==0 or x==K-1)and(j==0 or j==K-3))or j>K-3)):
            print('*',end='')
        else:
            print(' ',end='')

    def o1(x,j,K):
        global a
        if (j==a or j==K//2 or x==K-1):
            print('*',end='')
            a-=1
        else:
            print(' ',end='')
    def o2(x,j,K):
        global b
        if ((x==0 or x==K-1 or j==b or(x==1 and j==1))and(not((x==0 and j==1)or((x==0)and(j==0 or j==K-1))or(x==K-1 and j==0)))):
            print("*",end='')
            if j==b:
                b-=1
        else:
            print(' ',end='')
    def o3(x,j,K):
        if (x==0 or x==K-1 or x==K//2 or j==K-1)and(not((x==0 or x==K-1 or x==K//2)and(j==0 or j==K-1))):
            print('*',end='')
        else:
            print(' ',end='')
    def o4(x,j,K):
        global c
        if (j==K-2 or (j==K-c and x<=K//2)or x==K//2)and(not(j<1)):
            print('*',end='')
            c+=1
        else:
            print(' ',end='')
    def o5(x,j,K):
        if (x==0 or x==K-1 or x== K//2 or j==0 or(j==K-1 and x>K//2))and(not(((x==K//2 or x==K-1)and(j==K-1))or((x in range(((K//2)+1),K-1)) and(j==0)))):
            print('*',end='')
        else:
            print(' ',end='')
    def o6(x,j,K):
        if (x==0 or x==K-1 or x== K//2 or j==0 or(j==K-1 and x>K//2))and(not((x==K//2 and j==K-1)or((x==0 or x==K-1)and(j==0 or j==K-1)))):
            print('*',end='')
        else:
            print(' ',end='')
    def o7(x,j,K):
        global b
        if x==0 or x+j==K-1:
            print('*',end='')
        else:
            print(' ',end='')
    def o8(x,j,K):
        if (x==0 or j==0 or x==K//2 or j==K-1 or x==K-1)and(not((x==0 or x==K//2 or x==K-1)and(j==0 or j==K-1))):
            print('*',end='')
        else:
            print(' ',end='')
    def o9(x,j,K):
        if (x==0 or (j==0 and (x<=K//2 or x==K-2)) or x==K//2 or j==K-1 or x==K-1)and(not(((x==0 or x==K//2 or x==K-1)and(j==0))or((x==0 or x==K-1)and(j==K-1)))):
            print('*',end='')
        else:
            print(' ',end='')

    def pattern1(n,K):
        for i in str(n):
            print()
            for x in range(K):
                for j in range(K):
                    i=int(i)
                    if i==1:
                        o1(x,j,K)
                    elif i==0:
                        o0(x,j,K)
                    elif i==2:
                        o2(x,j,K)
                    elif i==3:
                        o3(x,j,K)
                    elif i==4:
                        o4(x,j,K)
                    elif i==5:
                        o5(x,j,K)
                    elif i==6:
                        o6(x,j,K)
                    elif i==7:
                        o7(x,j,K)
                    elif i==8:
                        o8(x,j,K)
                    else:
                        o9(x,j,K)
                print()
    def pattern_even(n,K):        
        print("Even Digits :")
        for i in str(n):
            list=[1,3,5,7,9]
            if int(i) in list:
                continue
            for x in range(K):
                print()
                for j in range(K):
                    i=int(i)
                    if i==0:
                        o0(x,j,K)
                    elif i==2:
                        o2(x,j,K)
                    elif i==4:
                        o4(x,j,K)
                    elif i==6:
                        o6(x,j,K)
                    elif i==8:
                        o8(x,j,K)
            print()

    def pattern_odd(n,K):        
        print("Odd Digits :")
        list=[1,3,5,7,9]
        for i in str(n):
            if int(i) not in list:
                continue
            for x in range(K):
                print()
                for j in range(K):
                    i=int(i)
                    if i==1:
                        o1(x,j,K)
                    elif i==3:
                        o3(x,j,K)
                    elif i==5:
                        o5(x,j,K)
                    elif i==7:
                        o7(x,j,K)
                    elif i==9:
                        o9(x,j,K)
            print()

    a=(K//2)-1
    b=K-1
    c=2
    print("1. To display the pattern of all digits of the given number :")
    print("2. To display the pattern of all even digits of the given number :")
    print("3. To display the pattern of all odd digits of the given number :")
    print("enter your choice :")
    ch=int(input())
    if ch==1:
        pattern1(n,K)
    elif ch==2:
        pattern_even(n,K)
    elif ch==3:
        pattern_odd(n,K)
    else :
        print("THE END ...")
        break
    print()
# Out:
# 0123456789
# 7
# 1. To display the pattern of all digits of the given number :
# 2. To display the pattern of all even digits of the given number :
# 3. To display the pattern of all odd digits of the given number :
# enter your choice :
# 1
#
#   **
# *  *
#    *
#    *
#    *
#    *
# *******
#
#   ****
#  *    *
#      *
#     *
#    *
#   *
#  ******
#
#  *****
#       *
#       *
#  *****
#       *
#       *
#  *****
#
#      *
#     **
#   *  *
#  ******
#      *
#      *
#      *
#
# *******
# *
# *
# ******
#       *
#       *
# ******
#
#  *****
# *
# *
# ******
# *     *
# *     *
#  *****
#
# *******
#      *
#     *
#    *
#   *
#  *
# *
#
#  *****
# *     *
# *     *
#  *****
# *     *
# *     *
#  *****
#
#  *****
# *     *
# *     *
#  ******
#       *
# *     *
#  *****
#
# 1. To display the pattern of all digits of the given number :
# 2. To display the pattern of all even digits of the given number :
# 3. To display the pattern of all odd digits of the given number :
# enter your choice :
# 2
# Even Digits :
#
#   ****
#  *    *
#      *
#     *
#    *
#   *
#  ******
#
#      *
#     **
#   *  *
#  ******
#      *
#      *
#      *
#
#  *****
# *
# *
# ******
# *     *
# *     *
#  *****
#
#  *****
# *     *
# *     *
#  *****
# *     *
# *     *
#  *****
#
# 1. To display the pattern of all digits of the given number :
# 2. To display the pattern of all even digits of the given number :
# 3. To display the pattern of all odd digits of the given number :
# enter your choice :
# 3
# Odd Digits :
#
#   **
# *  *
#    *
#    *
#    *
#    *
# *******
#
#  *****
#       *
#       *
#  *****
#       *
#       *
#  *****
#
# *******
# *
# *
# ******
#       *
#       *
# ******
#
# *******
#      *
#     *
#    *
#   *
#  *
# *
#
#  *****
# *     *
# *     *
#  ******
#       *
# *     *
#  *****
#
# 1. To display the pattern of all digits of the given number :
# 2. To display the pattern of all even digits of the given number :
# 3. To display the pattern of all odd digits of the given number :
# enter your choice :
# 4
# THE END ...
